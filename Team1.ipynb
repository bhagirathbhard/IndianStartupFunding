# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagirathbhard/BA775_Notebook/blob/nightly/Team1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Startup Investments in India Market
# **By: Yicheng Jiang, Bhagirath Bhardwaj, Agnes Shih, Paul Seiters, and Siddharth Bookinkere**

# %% [markdown]
# ## Outline
#
# #### I. Project Overview, Data Source Description and Exploratory Statistics
#
#       1. Project Overview
#       2. Data Source Description
#       3. Exploratory Statistics
#
# #### II. What year had the most amount of start ups funded? What is the overall trend of Start up funding in India?
#
# #### III. What type of start ups are funded the most?
#
# #### IV: What cities in India had the highest amount of start ups funded in India? Is there any reason that comes to attention?
#
# #### V: What startups had the highest funded every year?
#
# #### VIII: Conclusion
#
# #### IX: Public Tableau Dashboard

# %% [markdown]
# # I. Project Overview, Data Source Description and Exploratory Statistics
#       1. Project Overview
#
# We are an old and very traditional money manager from the USA, investing almost exclusively in the US. After the US economy had lost a lot of its growth trajectory and the FED predicted GDP growth to linger below a mere 2% annually, our clients have been running from our investment products. Where are they all going? After booking a tee time with one of our long-time clients, we heard some adolescents with smartphones talking about the start-up scene in India. There were wild tales about startups with valuations beyond $1B, called unicorns. Apparently, there was not a hint of a slowing economy over there. Is it time to go international? After multiple people confirmed the start-up hype in India, we concluded that it is time to get ourselves a snapshot of what is going on in India. Who is investing? Where are they investing? And most importantly, which companies are they investing in? As a team, we perform data cleaning, exploratory data analysis, and finally, create a visualization in Tableau. Also, we chose the Indian Startup Funding dataset collected from multiple sources because of the varied types of funding covered, the sizable number of observations, and the time coverage from 2015 until May 2022, including the Covid-19 phase.

# %% [markdown]
#     2. Data Source Description
#
# 1.   Indian Startup Funding & Investment Chart [2021] (Trak.in link)
# 2.   Indian Startups - Funding & Investors Data [2018-2021] (Kaggle link)
# 3.   Indian Startup Funding & Investment Chart [2021] (Trak.in link)
# 4.   Indian Startups - Funding Data [2022] (Kaggle link)
# 5.   Funding details of the startups in India (Kaggle link)

# %% [markdown]
#     3. Preview of the Dataset

# %%
#Connect to Google Big Query
from google.colab import auth
auth.authenticate_user()

# %%
## Perform (Table Union) PLEASE DO NOT TOUCH -- VICTOR
# %%bigquery --project=ba775-team-project-a01

SELECT Funding_Year,Company_Name,Sector,Location As HeadQuarter,Investor,Stage,USD_Amount,What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2022`
UNION ALL
SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2021`
UNION ALL
SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_is_does AS What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2020`
UNION ALL
SELECT Funding_Year,Company AS Company_Brand,Sector,HeadQuarter,Investor,Stage,Amount___ AS USD_Amount,What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2019`
UNION ALL
SELECT Funding_Year,Company_Name AS Company_Brand,Industry as Sector,Location as HeadQuarter,Investor,Round AS Stage,USD_Amount,About_Company as What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2018`
UNION ALL
SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,_Amount AS USD_Amount,What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2017`
UNION ALL
SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2016`
UNION ALL
SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Investment_Type as Stage,USD_Amount,What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2015`
;
# Out:
#       Funding_Year            Company_Name         Sector    HeadQuarter  \
# 0             2019                Nu Genes       AgriTech      Telangana
# 1             2019                Pumpkart  E-marketplace     Chandigarh
# 2             2019         Smart Institute         Edtech          Surat
# 3             2019                Kratikal     Technology  Uttar pradesh
# 4             2019         Ess Kay Fincorp        Banking      Rajasthan
# ...            ...                     ...            ...            ...
# 5689          2020           Max wholesale     E-commerce      New Delhi
# 5690          2020  High Street Essentials      Ecommerce      New Delhi
# 5691          2020                  Agro2o       Agritech      New Delhi
# 5692          2020        Eupheus Learning         Edtech      New Delhi
# 5693          2020       Harappa Education         Edtech      New Delhi
#
#                                                Investor         Stage  \
# 0              Innovation in Food and Agriculture (IFA)          None
# 1                                            Dinesh Dua          None
# 2                                         HNI investors          None
# 3             Gilda VC, Art Venture, Rajeev Chitrabhanu  Pre-series A
# 4        TPG, Norwest Venture Partners, Evolvence India          None
# ...                                                 ...           ...
# 5689  Al Falaj Commercial Investment Co, Vistra ITCL...          None
# 5690                      SAIF Partners, India Quotient  Pre series C
# 5691                              Mumbai Angels Network          None
# 5692                                       Yuj Ventures      Series A
# 5693                     James Murdoch-led Lupa Systems          None
#
#        USD_Amount                                       What_it_does
# 0         6000000  It is a seed company engaged in production, pr...
# 1     Undisclosed   B2B model for appliances and electrical products
# 2         1500000                         A platform to learn online
# 3         1000000                  Provides cyber security solutions
# 4        33000000              Organised Non-Banking Finance Company
# ...           ...                                                ...
# 5689      603,000  MaxWholesale is an online distributor that pro...
# 5690    2,743,000  The parent company of women's fashion brands F...
# 5691  Undisclosed  It develops products focused on making hydropo...
# 5692    4,300,000  Provides technology-led, subscription-based le...
# 5693  Undisclosed     Provides online courses on foundational skills
#
# [5694 rows x 8 columns]

# %%
## Perform (Table Union)
# %%bigquery --project=ba775-team-project-a01

SELECT Funding_Year,Company_Name,Sector,Location As HeadQuarter,Investor,Stage,USD_Amount,What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2022`
UNION ALL
SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2021`
UNION ALL
SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_is_does AS What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2020`
UNION ALL
SELECT Funding_Year,Company AS Company_Brand,Sector,HeadQuarter,Investor,Stage,Amount___ AS USD_Amount,What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2019`
UNION ALL
SELECT Funding_Year,Company_Name AS Company_Brand,Industry as Sector,Location as HeadQuarter,Investor,Round AS Stage,USD_Amount,About_Company as What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2018`
UNION ALL
SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,_Amount AS USD_Amount,What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2017`
UNION ALL
SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2016`
UNION ALL
SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Investment_Type as Stage,USD_Amount,What_it_does
FROM `ba775-team-project-a01.Indianstartups.India_Funding_2015`
;
# Out:
#       Funding_Year            Company_Name                             Sector  \
# 0             2019                Nu Genes                           AgriTech
# 1             2019                Pumpkart                      E-marketplace
# 2             2019         Smart Institute                             Edtech
# 3             2019                Kratikal                         Technology
# 4             2019         Ess Kay Fincorp                            Banking
# ...            ...                     ...                                ...
# 5689          2021        Eupheus Learning                         E-learning
# 5690          2021  Boutique Spirit Brands                     Wine & Spirits
# 5691          2021                 Paytail                 Financial Services
# 5692          2021                  GoKwik  Information Technology & Services
# 5693          2021                  Vahdam                   Food & Beverages
#
#         HeadQuarter                                           Investor  \
# 0         Telangana           Innovation in Food and Agriculture (IFA)
# 1        Chandigarh                                         Dinesh Dua
# 2             Surat                                      HNI investors
# 3     Uttar pradesh          Gilda VC, Art Venture, Rajeev Chitrabhanu
# 4         Rajasthan     TPG, Norwest Venture Partners, Evolvence India
# ...             ...                                                ...
# 5689      New Delhi                                    Lightrock India
# 5690      New Delhi  IIFL﻿, ﻿Anicut Angel Fund﻿, ﻿Kae Capital﻿, Tra...
# 5691      New Delhi                                      Cholamandalam
# 5692      New Delhi  Matrix Partners India, Jitendra Gupta, RTP Global
# 5693      New Delhi                                           IIFL AMC
#
#              Stage   USD_Amount  \
# 0             None      6000000
# 1             None  Undisclosed
# 2             None      1500000
# 3     Pre-series A      1000000
# 4             None     33000000
# ...            ...          ...
# 5689      Series C   10,000,000
# 5690          None   10,000,000
# 5691          Seed    1,500,000
# 5692  Pre-series A    5,000,000
# 5693      Series D   20,000,000
#
#                                            What_it_does
# 0     It is a seed company engaged in production, pr...
# 1      B2B model for appliances and electrical products
# 2                            A platform to learn online
# 3                     Provides cyber security solutions
# 4                 Organised Non-Banking Finance Company
# ...                                                 ...
# 5689  Offer pedagogically differentiated technology ...
# 5690  Boutique Spirit Brands is a leading Brand crea...
# 5691  Paytail is revolutionizing the offline commerc...
# 5692  GoKwik is a platform for solving shopping expe...
# 5693  VAHDAM is among the world’s first vertically i...
#
# [5694 rows x 8 columns]

# %% [markdown]
# **Bhagirath**
#
# Dataset Qualification Criteria -
#
#        8+ Columns
#        5k+ Rows

# %%
# %%bigquery --project=ba775-team-project-a01
# WITH Indian_Startup AS(
# SELECT Funding_Year,Company_Name,Sector,Location As HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2022`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2021`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_is_does AS What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2020`
# UNION ALL
# SELECT Funding_Year,Company AS Company_Brand,Sector,HeadQuarter,Investor,Stage,Amount___ AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2019`
# UNION ALL
# SELECT Funding_Year,Company_Name AS Company_Brand,Industry as Sector,Location as HeadQuarter,Investor,Round AS Stage,USD_Amount,About_Company as What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2018`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,_Amount AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2017`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2016`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Investment_Type as Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2015`
# )
#
# SELECT COUNT(*) AS number_of_rows
# FROM `Indian_Startup`;
# Out:
#    number_of_rows
# 0            5694

# %%
# %%bigquery --project=ba775-team-project-a01
# WITH Indian_Startup AS(
# SELECT Funding_Year,Company_Name,Sector,Location As HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2022`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2021`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_is_does AS What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2020`
# UNION ALL
# SELECT Funding_Year,Company AS Company_Brand,Sector,HeadQuarter,Investor,Stage,Amount___ AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2019`
# UNION ALL
# SELECT Funding_Year,Company_Name AS Company_Brand,Industry as Sector,Location as HeadQuarter,Investor,Round AS Stage,USD_Amount,About_Company as What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2018`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,_Amount AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2017`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2016`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Investment_Type as Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2015`
# )
#
# SELECT COUNT(Funding_Year) AS null_count
# FROM `Indian_Startup`
# WHERE Funding_Year IS NULL;
# Out:
#    null_count
# 0           0

# %% [markdown]
# # Inspecting the Dataset
#
# How many unique cities are in the dataset?

# %%
# %%bigquery --project=ba775-team-project-a01
# WITH Indian_Startup AS(
# SELECT Funding_Year,Company_Name,Sector,Location As HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2022`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2021`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_is_does AS What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2020`
# UNION ALL
# SELECT Funding_Year,Company AS Company_Brand,Sector,HeadQuarter,Investor,Stage,Amount___ AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2019`
# UNION ALL
# SELECT Funding_Year,Company_Name AS Company_Brand,Industry as Sector,Location as HeadQuarter,Investor,Round AS Stage,USD_Amount,About_Company as What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2018`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,_Amount AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2017`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2016`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Investment_Type as Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2015`
# )
#
# SELECT HeadQuarter, COUNT(*)
# FROM `Indian_Startup`
# WHERE HeadQuarter IS NOT NULL
# GROUP BY HeadQuarter
# ORDER BY HeadQuarter DESC;
# Out:
#                     HeadQuarter  f0_
# 0                         Noida    1
# 1                     New Delhi    3
# 2                        Mumbai    1
# 3                       Gurgaon    4
# 4                     Bangalore    1
# ..                          ...  ...
# 212  Alibaba, Foxconn, Softbank    1
# 213                   Ahmedabad   69
# 214                   Ahmadabad    6
# 215                   Ahemdabad    1
# 216                        Agra    2
#
# [217 rows x 2 columns]

# %%
# %%bigquery --project=ba775-team-project-a01
#
# WITH cte_table AS(
# SELECT Funding_Year,Company_Name,Sector,Location As HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2022`)
#
# SELECT * from cte_table;
# Out:
#      Funding_Year   Company_Name                             Sector  \
# 0            2022           Dyte      IT Services and IT Consulting
# 1            2022  Kirana Bazaar                      Oline grocery
# 2            2022          Phool           Enviromental Engineering
# 3            2022        Doceree  Information Technology & Services
# 4            2022           Acko                   Health insurance
# ..            ...            ...                                ...
# 423          2022           Kolo                       Construction
# 424          2022           None                  Retail Technology
# 425          2022        BharatX                 Financial Services
# 426          2022           Hono                           Software
# 427          2022        MoEVing                   Electric Vehicle
#
#     HeadQuarter                                   Investor        Stage  \
# 0     Bengaluru                                  Multiples  undisclosed
# 1       Gurgaon                                  Multiples  undisclosed
# 2        kanpur                                  Multiples  undisclosed
# 3    Parsippany                                  Multiples  undisclosed
# 4        Mumbai                                  Multiples     Series D
# ..          ...                                        ...          ...
# 423   Singapore               Better Capital and RTP Globa         Seed
# 424     Gurgaon  Multipoint Capital and Btomorrow Ventures    $Series A
# 425    Benglaru         Ankur Aggarwal and Vikas Choudhury         Seed
# 426     Haryana                Harsh Gupta and Amit Khanna     Series A
# 427     Gurgaon              Stride Ventures and TradeCred         Seed
#
#       USD_Amount                                       What_it_does
# 0     15,300,000  Dyte provides the easiest way to add real-time...
# 1     32,800,000  Kirana Bazaar is a neighborhood store network ...
# 2      9,400,000                    Phool is a biomaterial startup.
# 3     12,000,000  Doceree is a fully integrated programmatic ad ...
# 4    458,000,000  Acko is a digital insurance company with a lic...
# ..           ...                                                ...
# 423    4,600,000                              Home Construction App
# 424    6,400,000  ParallelDots is an image recognition platform ...
# 425    4,800,000  BharatX is a Embedded Consumer Credit company ...
# 426   39,000,000   Hono is a provider of HR solutions and services.
# 427    1,000,000  MoEVing is a technology-driven firm with the g...
#
# [428 rows x 8 columns]

# %% [markdown]
# # Questions Answered (Bhagirath)

# %% [markdown]
# What year had the most amount of start ups funded? What is the overall trend of Start up funding in India?
#
# **Answer: 2021**

# %%
# %%bigquery --project=ba775-team-project-a01
#
# WITH test_table AS(
# SELECT Funding_Year,Company_Name,Sector,Location As HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2022`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2021`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_is_does AS What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2020`
# UNION ALL
# SELECT Funding_Year,Company AS Company_Brand,Sector,HeadQuarter,Investor,Stage,Amount___ AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2019`
# UNION ALL
# SELECT Funding_Year,Company_Name AS Company_Brand,Industry as Sector,Location as HeadQuarter,Investor,Round AS Stage,USD_Amount,About_Company as What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2018`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,_Amount AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2017`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2016`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Investment_Type as Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2015`
# )
#
# SELECT Funding_Year, COUNT(*) AS startups_funded
# FROM test_table
# GROUP BY Funding_Year
# ORDER BY Funding_Year ASC;
# Out:
#    Funding_Year  startups_funded
# 0          2015              679
# 1          2016             1018
# 2          2017              690
# 3          2018              526
# 4          2019               89
# 5          2020             1055
# 6          2021             1209
# 7          2022              428

# %% [markdown]
# How many companies founded which are Software Related?
#
# **Answer: 41**

# %%
# %%bigquery --project=ba775-team-project-a01
#
# WITH test_table AS(
# SELECT Funding_Year,Company_Name,Sector,Location As HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2022`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2021`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_is_does AS What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2020`
# UNION ALL
# SELECT Funding_Year,Company AS Company_Brand,Sector,HeadQuarter,Investor,Stage,Amount___ AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2019`
# UNION ALL
# SELECT Funding_Year,Company_Name AS Company_Brand,Industry as Sector,Location as HeadQuarter,Investor,Round AS Stage,USD_Amount,About_Company as What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2018`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,_Amount AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2017`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2016`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Investment_Type as Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2015`
# )
#
# SELECT Sector, COUNT(*) AS Software_Related
# FROM test_table
# WHERE Sector LIKE '%Software%'
# GROUP BY Sector
# ORDER BY Sector DESC;
# Out:
#                                                Sector  Software_Related
# 0                    Contact Center Software Platform                 1
# 1                     Spa & Salon Management Software                 1
# 2                           Software, Virtual Reality                 1
# 3                                    Software company                 3
# 4                                    Software Startup                 2
# 5                                Software Development                 4
# 6                                    Software Company                 1
# 7                                            Software                16
# 8                       Sales & Productivity Software                 1
# 9                   Psychometric Test Online Software                 1
# 10                             Online Games, Software                 1
# 11                           Mobile, Software, Travel                 1
# 12                        Mobile Compression Software                 1
# 13                                 Internet, Software                 1
# 14  Information Services, Information Technology, ...                 1
# 15                 Hotel Mobile CRM Software platform                 1
# 16       Government, Information Technology, Software                 1
# 17                         Financial Markets Software                 1
# 18  Enterprise Software, Health Care, Hospital, Pa...                 1
# 19                                Enterprise Software                 2
# 20  Education, Information Technology, Internet, M...                 1
# 21  EdTech, Education, Enterprise Software, Peer t...                 1
# 22              Ecommerce Marketing Software Platform                 1
# 23                      Data Center Software platform                 1
# 24  Customer Service, Software, Video, Video Strea...                 1
# 25              Content Management Software Solutions                 1
# 26  Consumer Electronics, Embedded Systems, Hardwa...                 1
# 27                      Computer, Furniture, Software                 1
# 28       Computer, FinTech, Risk Management, Software                 1
# 29                                  Computer Software                46
# 30        Communities, Leisure, Mobile Apps, Software                 1
# 31                          Cloud Enterprise Software                 1
# 32  Cloud Computing, Enterprise Software, Network ...                 1
# 33                Cloud Computing, Computer, Software                 1
# 34          Cloud Computing, Computer, SaaS, Software                 1
# 35   Blockchain, Developer Tools, Enterprise Software                 1
# 36  Big Data, Data Visualization, Logistics, Software                 1
# 37  Artificial Intelligence, Product Search, SaaS,...                 1
# 38                Apps, Mobile, Mobile Apps, Software                 1
# 39  Apps, Collaboration, Developer Platform, Enter...                 1
# 40  Analytics, Computer Vision, Enterprise Softwar...                 1

# %%
# %%bigquery --project=ba775-team-project-a01
#
# WITH test_table AS(
# SELECT Funding_Year,Company_Name,Sector,Location As HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2022`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2021`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_is_does AS What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2020`
# UNION ALL
# SELECT Funding_Year,Company AS Company_Brand,Sector,HeadQuarter,Investor,Stage,Amount___ AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2019`
# UNION ALL
# SELECT Funding_Year,Company_Name AS Company_Brand,Industry as Sector,Location as HeadQuarter,Investor,Round AS Stage,USD_Amount,About_Company as What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2018`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,_Amount AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2017`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2016`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Investment_Type as Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2015`
# )
#
# SELECT * FROM test_table WHERE Sector = 'Technology' AND HeadQuarter = 'Bangalore' ORDER BY USD_Amount ASC;

# %% [markdown]
# # Questions Answered (Agnes)

# %% [markdown]
# ## 1. Which Technology company receives the highest funding in Bangalore? Answer: QTalk		    (Agnes)

# %%
# %%bigquery --project=ba775-team-project-a01
#
# WITH test_table AS(
# SELECT Funding_Year,Company_Name,Sector,Location As HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2022`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2021`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_is_does AS What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2020`
# UNION ALL
# SELECT Funding_Year,Company AS Company_Brand,Sector,HeadQuarter,Investor,Stage,Amount___ AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2019`
# UNION ALL
# SELECT Funding_Year,Company_Name AS Company_Brand,Industry as Sector,Location as HeadQuarter,Investor,Round AS Stage,USD_Amount,About_Company as What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2018`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,_Amount AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2017`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2016`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Investment_Type as Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2015`
# )
#
# SELECT * FROM test_table WHERE Sector = 'Technology' AND HeadQuarter = 'Bangalore' ORDER BY USD_Amount ASC;
# Out:
#      Funding_Year           Company_Name      Sector HeadQuarter  \
# 0            2020                  QTalk  Technology   Bangalore
# 1            2017             MergerWare  Technology   Bangalore
# 2            2016                Intgrea  Technology   Bangalore
# 3            2016                 RayIOT  Technology   Bangalore
# 4            2016                Cyclops  Technology   Bangalore
# ..            ...                    ...         ...         ...
# 121          2016             ShubhLoans  Technology   Bangalore
# 122          2016                 Vehico  Technology   Bangalore
# 123          2016               MoEngage  Technology   Bangalore
# 124          2016           Ten3t Health  Technology   Bangalore
# 125          2016  Pandorum Technologies  Technology   Bangalore
#
#                                      Investor         Stage USD_Amount  \
# 0    Accel India, Lightspeed Venture Partners    Seed Round  1,600,000
# 1                            Philippe Bouchet  Seed Funding     100000
# 2                        Undisclosed Investor  Seed Funding     100000
# 3                             HAX Accelerator  Seed Funding     100000
# 4                             Kalaari Capital  Seed Funding     100000
# ..                                        ...           ...        ...
# 121              Sanjai Vohra, V. Bunty Bohra  Seed Funding        N/A
# 122         Calcutta Angel Network, Appliyifi  Seed Funding        N/A
# 123                      Anand Chandrasekaran  Seed Funding        N/A
# 124   V. Krishna Prasad, Bhupen Shah & Others  Seed Funding        N/A
# 125               Sachin Bansal, Binny Bansal  Seed Funding        N/A
#
#                                           What_it_does
# 0                                   Smart Phone Dialer
# 1                          Software solutions for M&As
# 2                     Post merger Integration Partners
# 3                 Baby Monitoring Devices manufacturer
# 4     Clinical and Wearable Diagnostic Product creator
# ..                                                 ...
# 121           Consumer Finance & Credit Score platform
# 122                 Connected Transportation solutions
# 123             User analytics and engagement platform
# 124                 medical grade wearable patch maker
# 125  3D printed experimental Human Liver tissue cre...
#
# [126 rows x 8 columns]

# %% [markdown]
# ##2. How many companies have multiple investors in 2015-2022? Answer: 32 (Agnes)

# %%
# %%bigquery --project=ba775-team-project-a01
#
# WITH test_table AS(
# SELECT Funding_Year,Company_Name,Sector,Location As HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2022`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2021`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_is_does AS What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2020`
# UNION ALL
# SELECT Funding_Year,Company AS Company_Brand,Sector,HeadQuarter,Investor,Stage,Amount___ AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2019`
# UNION ALL
# SELECT Funding_Year,Company_Name AS Company_Brand,Industry as Sector,Location as HeadQuarter,Investor,Round AS Stage,USD_Amount,About_Company as What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2018`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,_Amount AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2017`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2016`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Investment_Type as Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2015`
# )
#
# SELECT * FROM test_table WHERE Investor = 'Multiples';
# Out:
#     Funding_Year      Company_Name                             Sector  \
# 0           2022              Dyte      IT Services and IT Consulting
# 1           2022     Kirana Bazaar                      Oline grocery
# 2           2022             Phool           Enviromental Engineering
# 3           2022           Doceree  Information Technology & Services
# 4           2022              Acko                   Health insurance
# 5           2022          FirstCry                    Online shopping
# 6           2022            Meesho                    Online shopping
# 7           2022          NoBroker                       Housing rent
# 8           2022             Paytm                 Financial services
# 9           2022         ShareChat                  Social networking
# 10          2022            Spinny                 Financial services
# 11          2022         Unacademy                         E-learning
# 12          2022     Urban Company                         E-commerce
# 13          2022        Xpressbees               E-commerce Logistics
# 14          2022             Accel                 Financial services
# 15          2022         MTR Foods                     Food packaging
# 16          2022               Oyo                Travel Arrangements
# 17          2022          Eruditus               Education Management
# 18          2022            CARS24                         Automobile
# 19          2022          BharatPe                 Financial services
# 20          2022         Blackbuck               Information services
# 21          2022             Droom                         Automotive
# 22          2022        MindTickle                   Software company
# 23          2022           Vedantu                         E-learning
# 24          2022           CoinDCX                  Currency exchange
# 25          2022          Razorpay                 Financial services
# 26          2022           Licious                               Food
# 27          2022  CoinSwitch Kuber                 Financial services
# 28          2022              Zeta                 Financial services
# 29          2022  Verse Innovation                Internet Publishing
# 30          2022          Lenskart                         E-commerce
# 31          2022   Kogta Financial                 Financial Services
#
#       HeadQuarter   Investor        Stage      USD_Amount  \
# 0       Bengaluru  Multiples  undisclosed      15,300,000
# 1         Gurgaon  Multiples  undisclosed      32,800,000
# 2          kanpur  Multiples  undisclosed       9,400,000
# 3      Parsippany  Multiples  undisclosed      12,000,000
# 4          Mumbai  Multiples     Series D     458,000,000
# 5            Pune  Multiples  undisclosed          74,140
# 6       Bangalore  Multiples     Series F   1,100,000,000
# 7       Bangalore  Multiples     Series E     426,000,000
# 8           Noida  Multiples  undisclosed   1,200,000,000
# 9       Bangalore  Multiples     Series G   1,400,000,000
# 10           None  Multiples     Series E     513,500,000
# 11      Bangalore  Multiples     Series H     838,500,000
# 12        Gurgaon  Multiples     Series H     445,900,000
# 13           Pune  Multiples     Series F     577,600,000
# 14      Palo Alto  Multiples  undisclosed  18,300,000,000
# 15      Bangalore  Multiples  undisclosed     Undisclosed
# 16        Gurgaon  Multiples     Series F     550,000,000
# 17      Bangalore  Multiples     Series E   1,200,000,000
# 18        Gurgaon  Multiples     Series G   1,300,000,000
# 19      New delhi  Multiples     Series E     700,500,000
# 20      Bengaluru  Multiples     Series E     364,000,000
# 21        Haryana  Multiples     Series F     333,000,000
# 22  San Francisco  Multiples     Series E     281,000,000
# 23      Bangalore  Multiples     Series E     292,900,000
# 24          Mumba  Multiples     Series C     109,000,000
# 25      Bangalore  Multiples     Series F     741,600,000
# 26      Bengaluru  Multiples     Series F     488,700,000
# 27      Bangalore  Multiples     Series C     300,600,000
# 28  San Francisco  Multiples         None      30,000,000
# 29      Bengaluru  Multiples     Series J   1,700,000,000
# 30      Faridabad  Multiples     Series I     899,300,000
# 31         Jaipur  Multiples     Series D     111,000,000
#
#                                          What_it_does
# 0   Dyte provides the easiest way to add real-time...
# 1   Kirana Bazaar is a neighborhood store network ...
# 2                     Phool is a biomaterial startup.
# 3   Doceree is a fully integrated programmatic ad ...
# 4   Acko is a digital insurance company with a lic...
# 5   FirstCry is an online shopping store offering ...
# 6   Meesho operates as an online reselling platfor...
# 7   NoBroker is a real-estate platform that makes ...
# 8   Paytm is a digital payments start-up that offe...
# 9   ShareChat is a social networking and regional ...
# 10  Spinny is a used car buying platform enabling ...
# 11  Unacademy is an online learning platform that ...
# 12  Urban Company provides a marketplace for freel...
# 13  Xpressbees is an e-commerce logistics company ...
# 14  Accel is an early and growth-stage venture cap...
# 15               MTR Foods is a food products company
# 16  OYO is a global travel tech company that conne...
# 17  Eruditus provides global access to executive e...
# 18  CARS24 offers a tech-enabled marketplace for b...
# 19  BharatPe is a financial services platform that...
# 20  Blackbuck is an Indian logistics company that ...
# 21  Droom is a tech and data science-driven online...
# 22  MindTickle is a software company that offers s...
# 23  Vedantu is an interactive online tutoring plat...
# 24  CoinDCX operates as a cryptocurrency exchange ...
# 25  Razorpay is a platform that enables businesses...
# 26  Licious is an online meat and seafood ordering...
# 27  CoinSwitch Kuber is a cryptocurrency exchange ...
# 28  Zeta is a modern banking tech company providin...
# 29  Verse Innovation facilitates content curation ...
# 30  Lenskart is an India-based online shopping por...
# 31  Kogta Financial (I) Ltd is a retail focused No...

# %% [markdown]
# ##3. Total number of Consumer Internet companies invested in Private Equity?
# Answer: 360 (Agnes)

# %%
# %%bigquery --project=ba775-team-project-a01
#
# WITH test_table AS(
# SELECT Funding_Year,Company_Name,Sector,Location As HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2022`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2021`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_is_does AS What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2020`
# UNION ALL
# SELECT Funding_Year,Company AS Company_Brand,Sector,HeadQuarter,Investor,Stage,Amount___ AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2019`
# UNION ALL
# SELECT Funding_Year,Company_Name AS Company_Brand,Industry as Sector,Location as HeadQuarter,Investor,Round AS Stage,USD_Amount,About_Company as What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2018`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,_Amount AS USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2017`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2016`
# UNION ALL
# SELECT Funding_Year,Company_Brand,Sector,HeadQuarter,Investor,Investment_Type as Stage,USD_Amount,What_it_does
# FROM `ba775-team-project-a01.Indianstartups.India_Funding_2015`
# )
#
# SELECT * FROM test_table WHERE Sector = 'Consumer Internet' AND  Stage = 'Private Equity';
# Out:
#      Funding_Year    Company_Name             Sector HeadQuarter  \
# 0            2016            Alef  Consumer Internet      Mumbai
# 1            2016          Zebpay  Consumer Internet   Ahmedabad
# 2            2016      MakeMyTrip  Consumer Internet     Gurgaon
# 3            2016       FreshMenu  Consumer Internet   Bangalore
# 4            2016  Hike Messenger  Consumer Internet   New Delhi
# ..            ...             ...                ...         ...
# 355          2017       Fingerlix  Consumer Internet   Bangalore
# 356          2017     Bank Bazaar  Consumer Internet     Chennai
# 357          2017           Toppr  Consumer Internet      Mumbai
# 358          2017         ZipLoan  Consumer Internet   New Delhi
# 359          2017        Ola Cabs  Consumer Internet   Bangalore
#
#                                               Investor           Stage  \
# 0                         Tata Capital Innovation Fund  Private Equity
# 1         Arjun Handa, Amit Jindal, Nagendra Chaudhary  Private Equity
# 2                          Ctrip.com International Ltd  Private Equity
# 3          Zodius Capital, Lightspeed Venture Partners  Private Equity
# 4    Matt Mullenweg, Adam D’Angelo, Aditya Agarwal,...  Private Equity
# ..                                                 ...             ...
# 355                     Accel Partners, Zephyr Peacock  Private Equity
# 356                                           Experian  Private Equity
# 357  SAIF Partners, Helion Ventures, FIL Capital Ma...  Private Equity
# 358  Matrix Partners India, WaterBridge Ventures, W...  Private Equity
# 359                          ANI Technologies Pvt. Ltd  Private Equity
#
#     USD_Amount                            What_it_does
# 0      5000000                Cloud Mobility Solutions
# 1      1000000     Bitcoin Buying & Selling Mobile App
# 2    180000000    Online Travel/Hotel Booking platform
# 3     16500000  Online / Mobile Food Ordering platform
# 4          N/A                   P2P Messaging Service
# ..         ...                                     ...
# 355    7000000                    Food Ordering Portal
# 356    7000000            Online Financial Marketplace
# 357    7000000               Mobile based learning app
# 358    3000000                    SME lending platform
# 359    7700000          App based cab hailing services
#
# [360 rows x 8 columns]
